# %%
fullnames = ['Adductor femoris',
'Adductor longus',
'Biceps femoris anterior',
'Biceps femoris posterior',
'Extensor digitorum longus',
'Flexor digitorum longus',
'Flexor hallicus longus',
'Gluteus maximus',
'Gluteus medius',
'Gluteus minimus',
'Gracilis',
'Lateral gastrocnemius',
'Medial gastrocnemius',
'Peroneus brevis',
'Pectineus',
'Peroneus longus',
'Plantaris',
'Iliopsoas',
'Peroneus tertius',
'Pyriformis',
'Quadratus femoris',
'Rectus femoris',
'Sartorius',
'Semimembranossus',
'Soleus',
'Semitendinosus',
'Tibialis anterior',
'Tibialis posterior',
'Vastus intermedius',
'Vastus lateralis',
'Vastus medialis']

print("[")
for bound in ["upperbound", "lowerbound"]:
	for muscleNum in range(1,32):
		for alphaVal in [0.5,0.6,0.7,0.8,0.9]:
			print("{alpha: " + str(alphaVal) + ", muscleNum: " + str(muscleNum) + ", bound: '" + str(bound) + "', fullname: '" +  fullnames[muscleNum-1] + "'},")

print("]")
# Out:
# [
# {alpha: 0.5, muscleNum: 1, bound: 'upperbound', fullname: 'Adductor femoris'},
# {alpha: 0.6, muscleNum: 1, bound: 'upperbound', fullname: 'Adductor femoris'},
# {alpha: 0.7, muscleNum: 1, bound: 'upperbound', fullname: 'Adductor femoris'},
# {alpha: 0.8, muscleNum: 1, bound: 'upperbound', fullname: 'Adductor femoris'},
# {alpha: 0.9, muscleNum: 1, bound: 'upperbound', fullname: 'Adductor femoris'},
# {alpha: 0.5, muscleNum: 2, bound: 'upperbound', fullname: 'Adductor longus'},
# {alpha: 0.6, muscleNum: 2, bound: 'upperbound', fullname: 'Adductor longus'},
# {alpha: 0.7, muscleNum: 2, bound: 'upperbound', fullname: 'Adductor longus'},
# {alpha: 0.8, muscleNum: 2, bound: 'upperbound', fullname: 'Adductor longus'},
# {alpha: 0.9, muscleNum: 2, bound: 'upperbound', fullname: 'Adductor longus'},
# {alpha: 0.5, muscleNum: 3, bound: 'upperbound', fullname: 'Biceps femoris anterior'},
# {alpha: 0.6, muscleNum: 3, bound: 'upperbound', fullname: 'Biceps femoris anterior'},
# {alpha: 0.7, muscleNum: 3, bound: 'upperbound', fullname: 'Biceps femoris anterior'},
# {alpha: 0.8, muscleNum: 3, bound: 'upperbound', fullname: 'Biceps femoris anterior'},
# {alpha: 0.9, muscleNum: 3, bound: 'upperbound', fullname: 'Biceps femoris anterior'},
# {alpha: 0.5, muscleNum: 4, bound: 'upperbound', fullname: 'Biceps femoris posterior'},
# {alpha: 0.6, muscleNum: 4, bound: 'upperbound', fullname: 'Biceps femoris posterior'},
# {alpha: 0.7, muscleNum: 4, bound: 'upperbound', fullname: 'Biceps femoris posterior'},
# {alpha: 0.8, muscleNum: 4, bound: 'upperbound', fullname: 'Biceps femoris posterior'},
# {alpha: 0.9, muscleNum: 4, bound: 'upperbound', fullname: 'Biceps femoris posterior'},
# {alpha: 0.5, muscleNum: 5, bound: 'upperbound', fullname: 'Extensor digitorum longus'},
# {alpha: 0.6, muscleNum: 5, bound: 'upperbound', fullname: 'Extensor digitorum longus'},
# {alpha: 0.7, muscleNum: 5, bound: 'upperbound', fullname: 'Extensor digitorum longus'},
# {alpha: 0.8, muscleNum: 5, bound: 'upperbound', fullname: 'Extensor digitorum longus'},
# {alpha: 0.9, muscleNum: 5, bound: 'upperbound', fullname: 'Extensor digitorum longus'},
# {alpha: 0.5, muscleNum: 6, bound: 'upperbound', fullname: 'Flexor digitorum longus'},
# {alpha: 0.6, muscleNum: 6, bound: 'upperbound', fullname: 'Flexor digitorum longus'},
# {alpha: 0.7, muscleNum: 6, bound: 'upperbound', fullname: 'Flexor digitorum longus'},
# {alpha: 0.8, muscleNum: 6, bound: 'upperbound', fullname: 'Flexor digitorum longus'},
# {alpha: 0.9, muscleNum: 6, bound: 'upperbound', fullname: 'Flexor digitorum longus'},
# {alpha: 0.5, muscleNum: 7, bound: 'upperbound', fullname: 'Flexor hallicus longus'},
# {alpha: 0.6, muscleNum: 7, bound: 'upperbound', fullname: 'Flexor hallicus longus'},
# {alpha: 0.7, muscleNum: 7, bound: 'upperbound', fullname: 'Flexor hallicus longus'},
# {alpha: 0.8, muscleNum: 7, bound: 'upperbound', fullname: 'Flexor hallicus longus'},
# {alpha: 0.9, muscleNum: 7, bound: 'upperbound', fullname: 'Flexor hallicus longus'},
# {alpha: 0.5, muscleNum: 8, bound: 'upperbound', fullname: 'Gluteus maximus'},
# {alpha: 0.6, muscleNum: 8, bound: 'upperbound', fullname: 'Gluteus maximus'},
# {alpha: 0.7, muscleNum: 8, bound: 'upperbound', fullname: 'Gluteus maximus'},
# {alpha: 0.8, muscleNum: 8, bound: 'upperbound', fullname: 'Gluteus maximus'},
# {alpha: 0.9, muscleNum: 8, bound: 'upperbound', fullname: 'Gluteus maximus'},
# {alpha: 0.5, muscleNum: 9, bound: 'upperbound', fullname: 'Gluteus medius'},
# {alpha: 0.6, muscleNum: 9, bound: 'upperbound', fullname: 'Gluteus medius'},
# {alpha: 0.7, muscleNum: 9, bound: 'upperbound', fullname: 'Gluteus medius'},
# {alpha: 0.8, muscleNum: 9, bound: 'upperbound', fullname: 'Gluteus medius'},
# {alpha: 0.9, muscleNum: 9, bound: 'upperbound', fullname: 'Gluteus medius'},
# {alpha: 0.5, muscleNum: 10, bound: 'upperbound', fullname: 'Gluteus minimus'},
# {alpha: 0.6, muscleNum: 10, bound: 'upperbound', fullname: 'Gluteus minimus'},
# {alpha: 0.7, muscleNum: 10, bound: 'upperbound', fullname: 'Gluteus minimus'},
# {alpha: 0.8, muscleNum: 10, bound: 'upperbound', fullname: 'Gluteus minimus'},
# {alpha: 0.9, muscleNum: 10, bound: 'upperbound', fullname: 'Gluteus minimus'},
# {alpha: 0.5, muscleNum: 11, bound: 'upperbound', fullname: 'Gracilis'},
# {alpha: 0.6, muscleNum: 11, bound: 'upperbound', fullname: 'Gracilis'},
# {alpha: 0.7, muscleNum: 11, bound: 'upperbound', fullname: 'Gracilis'},
# {alpha: 0.8, muscleNum: 11, bound: 'upperbound', fullname: 'Gracilis'},
# {alpha: 0.9, muscleNum: 11, bound: 'upperbound', fullname: 'Gracilis'},
# {alpha: 0.5, muscleNum: 12, bound: 'upperbound', fullname: 'Lateral gastrocnemius'},
# {alpha: 0.6, muscleNum: 12, bound: 'upperbound', fullname: 'Lateral gastrocnemius'},
# {alpha: 0.7, muscleNum: 12, bound: 'upperbound', fullname: 'Lateral gastrocnemius'},
# {alpha: 0.8, muscleNum: 12, bound: 'upperbound', fullname: 'Lateral gastrocnemius'},
# {alpha: 0.9, muscleNum: 12, bound: 'upperbound', fullname: 'Lateral gastrocnemius'},
# {alpha: 0.5, muscleNum: 13, bound: 'upperbound', fullname: 'Medial gastrocnemius'},
# {alpha: 0.6, muscleNum: 13, bound: 'upperbound', fullname: 'Medial gastrocnemius'},
# {alpha: 0.7, muscleNum: 13, bound: 'upperbound', fullname: 'Medial gastrocnemius'},
# {alpha: 0.8, muscleNum: 13, bound: 'upperbound', fullname: 'Medial gastrocnemius'},
# {alpha: 0.9, muscleNum: 13, bound: 'upperbound', fullname: 'Medial gastrocnemius'},
# {alpha: 0.5, muscleNum: 14, bound: 'upperbound', fullname: 'Peroneus brevis'},
# {alpha: 0.6, muscleNum: 14, bound: 'upperbound', fullname: 'Peroneus brevis'},
# {alpha: 0.7, muscleNum: 14, bound: 'upperbound', fullname: 'Peroneus brevis'},
# {alpha: 0.8, muscleNum: 14, bound: 'upperbound', fullname: 'Peroneus brevis'},
# {alpha: 0.9, muscleNum: 14, bound: 'upperbound', fullname: 'Peroneus brevis'},
# {alpha: 0.5, muscleNum: 15, bound: 'upperbound', fullname: 'Pectineus'},
# {alpha: 0.6, muscleNum: 15, bound: 'upperbound', fullname: 'Pectineus'},
# {alpha: 0.7, muscleNum: 15, bound: 'upperbound', fullname: 'Pectineus'},
# {alpha: 0.8, muscleNum: 15, bound: 'upperbound', fullname: 'Pectineus'},
# {alpha: 0.9, muscleNum: 15, bound: 'upperbound', fullname: 'Pectineus'},
# {alpha: 0.5, muscleNum: 16, bound: 'upperbound', fullname: 'Peroneus longus'},
# {alpha: 0.6, muscleNum: 16, bound: 'upperbound', fullname: 'Peroneus longus'},
# {alpha: 0.7, muscleNum: 16, bound: 'upperbound', fullname: 'Peroneus longus'},
# {alpha: 0.8, muscleNum: 16, bound: 'upperbound', fullname: 'Peroneus longus'},
# {alpha: 0.9, muscleNum: 16, bound: 'upperbound', fullname: 'Peroneus longus'},
# {alpha: 0.5, muscleNum: 17, bound: 'upperbound', fullname: 'Plantaris'},
# {alpha: 0.6, muscleNum: 17, bound: 'upperbound', fullname: 'Plantaris'},
# {alpha: 0.7, muscleNum: 17, bound: 'upperbound', fullname: 'Plantaris'},
# {alpha: 0.8, muscleNum: 17, bound: 'upperbound', fullname: 'Plantaris'},
# {alpha: 0.9, muscleNum: 17, bound: 'upperbound', fullname: 'Plantaris'},
# {alpha: 0.5, muscleNum: 18, bound: 'upperbound', fullname: 'Iliopsoas'},
# {alpha: 0.6, muscleNum: 18, bound: 'upperbound', fullname: 'Iliopsoas'},
# {alpha: 0.7, muscleNum: 18, bound: 'upperbound', fullname: 'Iliopsoas'},
# {alpha: 0.8, muscleNum: 18, bound: 'upperbound', fullname: 'Iliopsoas'},
# {alpha: 0.9, muscleNum: 18, bound: 'upperbound', fullname: 'Iliopsoas'},
# {alpha: 0.5, muscleNum: 19, bound: 'upperbound', fullname: 'Peroneus tertius'},
# {alpha: 0.6, muscleNum: 19, bound: 'upperbound', fullname: 'Peroneus tertius'},
# {alpha: 0.7, muscleNum: 19, bound: 'upperbound', fullname: 'Peroneus tertius'},
# {alpha: 0.8, muscleNum: 19, bound: 'upperbound', fullname: 'Peroneus tertius'},
# {alpha: 0.9, muscleNum: 19, bound: 'upperbound', fullname: 'Peroneus tertius'},
# {alpha: 0.5, muscleNum: 20, bound: 'upperbound', fullname: 'Pyriformis'},
# {alpha: 0.6, muscleNum: 20, bound: 'upperbound', fullname: 'Pyriformis'},
# {alpha: 0.7, muscleNum: 20, bound: 'upperbound', fullname: 'Pyriformis'},
# {alpha: 0.8, muscleNum: 20, bound: 'upperbound', fullname: 'Pyriformis'},
# {alpha: 0.9, muscleNum: 20, bound: 'upperbound', fullname: 'Pyriformis'},
# {alpha: 0.5, muscleNum: 21, bound: 'upperbound', fullname: 'Quadratus femoris'},
# {alpha: 0.6, muscleNum: 21, bound: 'upperbound', fullname: 'Quadratus femoris'},
# {alpha: 0.7, muscleNum: 21, bound: 'upperbound', fullname: 'Quadratus femoris'},
# {alpha: 0.8, muscleNum: 21, bound: 'upperbound', fullname: 'Quadratus femoris'},
# {alpha: 0.9, muscleNum: 21, bound: 'upperbound', fullname: 'Quadratus femoris'},
# {alpha: 0.5, muscleNum: 22, bound: 'upperbound', fullname: 'Rectus femoris'},
# {alpha: 0.6, muscleNum: 22, bound: 'upperbound', fullname: 'Rectus femoris'},
# {alpha: 0.7, muscleNum: 22, bound: 'upperbound', fullname: 'Rectus femoris'},
# {alpha: 0.8, muscleNum: 22, bound: 'upperbound', fullname: 'Rectus femoris'},
# {alpha: 0.9, muscleNum: 22, bound: 'upperbound', fullname: 'Rectus femoris'},
# {alpha: 0.5, muscleNum: 23, bound: 'upperbound', fullname: 'Sartorius'},
# {alpha: 0.6, muscleNum: 23, bound: 'upperbound', fullname: 'Sartorius'},
# {alpha: 0.7, muscleNum: 23, bound: 'upperbound', fullname: 'Sartorius'},
# {alpha: 0.8, muscleNum: 23, bound: 'upperbound', fullname: 'Sartorius'},
# {alpha: 0.9, muscleNum: 23, bound: 'upperbound', fullname: 'Sartorius'},
# {alpha: 0.5, muscleNum: 24, bound: 'upperbound', fullname: 'Semimembranossus'},
# {alpha: 0.6, muscleNum: 24, bound: 'upperbound', fullname: 'Semimembranossus'},
# {alpha: 0.7, muscleNum: 24, bound: 'upperbound', fullname: 'Semimembranossus'},
# {alpha: 0.8, muscleNum: 24, bound: 'upperbound', fullname: 'Semimembranossus'},
# {alpha: 0.9, muscleNum: 24, bound: 'upperbound', fullname: 'Semimembranossus'},
# {alpha: 0.5, muscleNum: 25, bound: 'upperbound', fullname: 'Soleus'},
# {alpha: 0.6, muscleNum: 25, bound: 'upperbound', fullname: 'Soleus'},
# {alpha: 0.7, muscleNum: 25, bound: 'upperbound', fullname: 'Soleus'},
# {alpha: 0.8, muscleNum: 25, bound: 'upperbound', fullname: 'Soleus'},
# {alpha: 0.9, muscleNum: 25, bound: 'upperbound', fullname: 'Soleus'},
# {alpha: 0.5, muscleNum: 26, bound: 'upperbound', fullname: 'Semitendinosus'},
# {alpha: 0.6, muscleNum: 26, bound: 'upperbound', fullname: 'Semitendinosus'},
# {alpha: 0.7, muscleNum: 26, bound: 'upperbound', fullname: 'Semitendinosus'},
# {alpha: 0.8, muscleNum: 26, bound: 'upperbound', fullname: 'Semitendinosus'},
# {alpha: 0.9, muscleNum: 26, bound: 'upperbound', fullname: 'Semitendinosus'},
# {alpha: 0.5, muscleNum: 27, bound: 'upperbound', fullname: 'Tibialis anterior'},
# {alpha: 0.6, muscleNum: 27, bound: 'upperbound', fullname: 'Tibialis anterior'},
# {alpha: 0.7, muscleNum: 27, bound: 'upperbound', fullname: 'Tibialis anterior'},
# {alpha: 0.8, muscleNum: 27, bound: 'upperbound', fullname: 'Tibialis anterior'},
# {alpha: 0.9, muscleNum: 27, bound: 'upperbound', fullname: 'Tibialis anterior'},
# {alpha: 0.5, muscleNum: 28, bound: 'upperbound', fullname: 'Tibialis posterior'},
# {alpha: 0.6, muscleNum: 28, bound: 'upperbound', fullname: 'Tibialis posterior'},
# {alpha: 0.7, muscleNum: 28, bound: 'upperbound', fullname: 'Tibialis posterior'},
# {alpha: 0.8, muscleNum: 28, bound: 'upperbound', fullname: 'Tibialis posterior'},
# {alpha: 0.9, muscleNum: 28, bound: 'upperbound', fullname: 'Tibialis posterior'},
# {alpha: 0.5, muscleNum: 29, bound: 'upperbound', fullname: 'Vastus intermedius'},
# {alpha: 0.6, muscleNum: 29, bound: 'upperbound', fullname: 'Vastus intermedius'},
# {alpha: 0.7, muscleNum: 29, bound: 'upperbound', fullname: 'Vastus intermedius'},
# {alpha: 0.8, muscleNum: 29, bound: 'upperbound', fullname: 'Vastus intermedius'},
# {alpha: 0.9, muscleNum: 29, bound: 'upperbound', fullname: 'Vastus intermedius'},
# {alpha: 0.5, muscleNum: 30, bound: 'upperbound', fullname: 'Vastus lateralis'},
# {alpha: 0.6, muscleNum: 30, bound: 'upperbound', fullname: 'Vastus lateralis'},
# {alpha: 0.7, muscleNum: 30, bound: 'upperbound', fullname: 'Vastus lateralis'},
# {alpha: 0.8, muscleNum: 30, bound: 'upperbound', fullname: 'Vastus lateralis'},
# {alpha: 0.9, muscleNum: 30, bound: 'upperbound', fullname: 'Vastus lateralis'},
# {alpha: 0.5, muscleNum: 31, bound: 'upperbound', fullname: 'Vastus medialis'},
# {alpha: 0.6, muscleNum: 31, bound: 'upperbound', fullname: 'Vastus medialis'},
# {alpha: 0.7, muscleNum: 31, bound: 'upperbound', fullname: 'Vastus medialis'},
# {alpha: 0.8, muscleNum: 31, bound: 'upperbound', fullname: 'Vastus medialis'},
# {alpha: 0.9, muscleNum: 31, bound: 'upperbound', fullname: 'Vastus medialis'},
# {alpha: 0.5, muscleNum: 1, bound: 'lowerbound', fullname: 'Adductor femoris'},
# {alpha: 0.6, muscleNum: 1, bound: 'lowerbound', fullname: 'Adductor femoris'},
# {alpha: 0.7, muscleNum: 1, bound: 'lowerbound', fullname: 'Adductor femoris'},
# {alpha: 0.8, muscleNum: 1, bound: 'lowerbound', fullname: 'Adductor femoris'},
# {alpha: 0.9, muscleNum: 1, bound: 'lowerbound', fullname: 'Adductor femoris'},
# {alpha: 0.5, muscleNum: 2, bound: 'lowerbound', fullname: 'Adductor longus'},
# {alpha: 0.6, muscleNum: 2, bound: 'lowerbound', fullname: 'Adductor longus'},
# {alpha: 0.7, muscleNum: 2, bound: 'lowerbound', fullname: 'Adductor longus'},
# {alpha: 0.8, muscleNum: 2, bound: 'lowerbound', fullname: 'Adductor longus'},
# {alpha: 0.9, muscleNum: 2, bound: 'lowerbound', fullname: 'Adductor longus'},
# {alpha: 0.5, muscleNum: 3, bound: 'lowerbound', fullname: 'Biceps femoris anterior'},
# {alpha: 0.6, muscleNum: 3, bound: 'lowerbound', fullname: 'Biceps femoris anterior'},
# {alpha: 0.7, muscleNum: 3, bound: 'lowerbound', fullname: 'Biceps femoris anterior'},
# {alpha: 0.8, muscleNum: 3, bound: 'lowerbound', fullname: 'Biceps femoris anterior'},
# {alpha: 0.9, muscleNum: 3, bound: 'lowerbound', fullname: 'Biceps femoris anterior'},
# {alpha: 0.5, muscleNum: 4, bound: 'lowerbound', fullname: 'Biceps femoris posterior'},
# {alpha: 0.6, muscleNum: 4, bound: 'lowerbound', fullname: 'Biceps femoris posterior'},
# {alpha: 0.7, muscleNum: 4, bound: 'lowerbound', fullname: 'Biceps femoris posterior'},
# {alpha: 0.8, muscleNum: 4, bound: 'lowerbound', fullname: 'Biceps femoris posterior'},
# {alpha: 0.9, muscleNum: 4, bound: 'lowerbound', fullname: 'Biceps femoris posterior'},
# {alpha: 0.5, muscleNum: 5, bound: 'lowerbound', fullname: 'Extensor digitorum longus'},
# {alpha: 0.6, muscleNum: 5, bound: 'lowerbound', fullname: 'Extensor digitorum longus'},
# {alpha: 0.7, muscleNum: 5, bound: 'lowerbound', fullname: 'Extensor digitorum longus'},
# {alpha: 0.8, muscleNum: 5, bound: 'lowerbound', fullname: 'Extensor digitorum longus'},
# {alpha: 0.9, muscleNum: 5, bound: 'lowerbound', fullname: 'Extensor digitorum longus'},
# {alpha: 0.5, muscleNum: 6, bound: 'lowerbound', fullname: 'Flexor digitorum longus'},
# {alpha: 0.6, muscleNum: 6, bound: 'lowerbound', fullname: 'Flexor digitorum longus'},
# {alpha: 0.7, muscleNum: 6, bound: 'lowerbound', fullname: 'Flexor digitorum longus'},
# {alpha: 0.8, muscleNum: 6, bound: 'lowerbound', fullname: 'Flexor digitorum longus'},
# {alpha: 0.9, muscleNum: 6, bound: 'lowerbound', fullname: 'Flexor digitorum longus'},
# {alpha: 0.5, muscleNum: 7, bound: 'lowerbound', fullname: 'Flexor hallicus longus'},
# {alpha: 0.6, muscleNum: 7, bound: 'lowerbound', fullname: 'Flexor hallicus longus'},
# {alpha: 0.7, muscleNum: 7, bound: 'lowerbound', fullname: 'Flexor hallicus longus'},
# {alpha: 0.8, muscleNum: 7, bound: 'lowerbound', fullname: 'Flexor hallicus longus'},
# {alpha: 0.9, muscleNum: 7, bound: 'lowerbound', fullname: 'Flexor hallicus longus'},
# {alpha: 0.5, muscleNum: 8, bound: 'lowerbound', fullname: 'Gluteus maximus'},
# {alpha: 0.6, muscleNum: 8, bound: 'lowerbound', fullname: 'Gluteus maximus'},
# {alpha: 0.7, muscleNum: 8, bound: 'lowerbound', fullname: 'Gluteus maximus'},
# {alpha: 0.8, muscleNum: 8, bound: 'lowerbound', fullname: 'Gluteus maximus'},
# {alpha: 0.9, muscleNum: 8, bound: 'lowerbound', fullname: 'Gluteus maximus'},
# {alpha: 0.5, muscleNum: 9, bound: 'lowerbound', fullname: 'Gluteus medius'},
# {alpha: 0.6, muscleNum: 9, bound: 'lowerbound', fullname: 'Gluteus medius'},
# {alpha: 0.7, muscleNum: 9, bound: 'lowerbound', fullname: 'Gluteus medius'},
# {alpha: 0.8, muscleNum: 9, bound: 'lowerbound', fullname: 'Gluteus medius'},
# {alpha: 0.9, muscleNum: 9, bound: 'lowerbound', fullname: 'Gluteus medius'},
# {alpha: 0.5, muscleNum: 10, bound: 'lowerbound', fullname: 'Gluteus minimus'},
# {alpha: 0.6, muscleNum: 10, bound: 'lowerbound', fullname: 'Gluteus minimus'},
# {alpha: 0.7, muscleNum: 10, bound: 'lowerbound', fullname: 'Gluteus minimus'},
# {alpha: 0.8, muscleNum: 10, bound: 'lowerbound', fullname: 'Gluteus minimus'},
# {alpha: 0.9, muscleNum: 10, bound: 'lowerbound', fullname: 'Gluteus minimus'},
# {alpha: 0.5, muscleNum: 11, bound: 'lowerbound', fullname: 'Gracilis'},
# {alpha: 0.6, muscleNum: 11, bound: 'lowerbound', fullname: 'Gracilis'},
# {alpha: 0.7, muscleNum: 11, bound: 'lowerbound', fullname: 'Gracilis'},
# {alpha: 0.8, muscleNum: 11, bound: 'lowerbound', fullname: 'Gracilis'},
# {alpha: 0.9, muscleNum: 11, bound: 'lowerbound', fullname: 'Gracilis'},
# {alpha: 0.5, muscleNum: 12, bound: 'lowerbound', fullname: 'Lateral gastrocnemius'},
# {alpha: 0.6, muscleNum: 12, bound: 'lowerbound', fullname: 'Lateral gastrocnemius'},
# {alpha: 0.7, muscleNum: 12, bound: 'lowerbound', fullname: 'Lateral gastrocnemius'},
# {alpha: 0.8, muscleNum: 12, bound: 'lowerbound', fullname: 'Lateral gastrocnemius'},
# {alpha: 0.9, muscleNum: 12, bound: 'lowerbound', fullname: 'Lateral gastrocnemius'},
# {alpha: 0.5, muscleNum: 13, bound: 'lowerbound', fullname: 'Medial gastrocnemius'},
# {alpha: 0.6, muscleNum: 13, bound: 'lowerbound', fullname: 'Medial gastrocnemius'},
# {alpha: 0.7, muscleNum: 13, bound: 'lowerbound', fullname: 'Medial gastrocnemius'},
# {alpha: 0.8, muscleNum: 13, bound: 'lowerbound', fullname: 'Medial gastrocnemius'},
# {alpha: 0.9, muscleNum: 13, bound: 'lowerbound', fullname: 'Medial gastrocnemius'},
# {alpha: 0.5, muscleNum: 14, bound: 'lowerbound', fullname: 'Peroneus brevis'},
# {alpha: 0.6, muscleNum: 14, bound: 'lowerbound', fullname: 'Peroneus brevis'},
# {alpha: 0.7, muscleNum: 14, bound: 'lowerbound', fullname: 'Peroneus brevis'},
# {alpha: 0.8, muscleNum: 14, bound: 'lowerbound', fullname: 'Peroneus brevis'},
# {alpha: 0.9, muscleNum: 14, bound: 'lowerbound', fullname: 'Peroneus brevis'},
# {alpha: 0.5, muscleNum: 15, bound: 'lowerbound', fullname: 'Pectineus'},
# {alpha: 0.6, muscleNum: 15, bound: 'lowerbound', fullname: 'Pectineus'},
# {alpha: 0.7, muscleNum: 15, bound: 'lowerbound', fullname: 'Pectineus'},
# {alpha: 0.8, muscleNum: 15, bound: 'lowerbound', fullname: 'Pectineus'},
# {alpha: 0.9, muscleNum: 15, bound: 'lowerbound', fullname: 'Pectineus'},
# {alpha: 0.5, muscleNum: 16, bound: 'lowerbound', fullname: 'Peroneus longus'},
# {alpha: 0.6, muscleNum: 16, bound: 'lowerbound', fullname: 'Peroneus longus'},
# {alpha: 0.7, muscleNum: 16, bound: 'lowerbound', fullname: 'Peroneus longus'},
# {alpha: 0.8, muscleNum: 16, bound: 'lowerbound', fullname: 'Peroneus longus'},
# {alpha: 0.9, muscleNum: 16, bound: 'lowerbound', fullname: 'Peroneus longus'},
# {alpha: 0.5, muscleNum: 17, bound: 'lowerbound', fullname: 'Plantaris'},
# {alpha: 0.6, muscleNum: 17, bound: 'lowerbound', fullname: 'Plantaris'},
# {alpha: 0.7, muscleNum: 17, bound: 'lowerbound', fullname: 'Plantaris'},
# {alpha: 0.8, muscleNum: 17, bound: 'lowerbound', fullname: 'Plantaris'},
# {alpha: 0.9, muscleNum: 17, bound: 'lowerbound', fullname: 'Plantaris'},
# {alpha: 0.5, muscleNum: 18, bound: 'lowerbound', fullname: 'Iliopsoas'},
# {alpha: 0.6, muscleNum: 18, bound: 'lowerbound', fullname: 'Iliopsoas'},
# {alpha: 0.7, muscleNum: 18, bound: 'lowerbound', fullname: 'Iliopsoas'},
# {alpha: 0.8, muscleNum: 18, bound: 'lowerbound', fullname: 'Iliopsoas'},
# {alpha: 0.9, muscleNum: 18, bound: 'lowerbound', fullname: 'Iliopsoas'},
# {alpha: 0.5, muscleNum: 19, bound: 'lowerbound', fullname: 'Peroneus tertius'},
# {alpha: 0.6, muscleNum: 19, bound: 'lowerbound', fullname: 'Peroneus tertius'},
# {alpha: 0.7, muscleNum: 19, bound: 'lowerbound', fullname: 'Peroneus tertius'},
# {alpha: 0.8, muscleNum: 19, bound: 'lowerbound', fullname: 'Peroneus tertius'},
# {alpha: 0.9, muscleNum: 19, bound: 'lowerbound', fullname: 'Peroneus tertius'},
# {alpha: 0.5, muscleNum: 20, bound: 'lowerbound', fullname: 'Pyriformis'},
# {alpha: 0.6, muscleNum: 20, bound: 'lowerbound', fullname: 'Pyriformis'},
# {alpha: 0.7, muscleNum: 20, bound: 'lowerbound', fullname: 'Pyriformis'},
# {alpha: 0.8, muscleNum: 20, bound: 'lowerbound', fullname: 'Pyriformis'},
# {alpha: 0.9, muscleNum: 20, bound: 'lowerbound', fullname: 'Pyriformis'},
# {alpha: 0.5, muscleNum: 21, bound: 'lowerbound', fullname: 'Quadratus femoris'},
# {alpha: 0.6, muscleNum: 21, bound: 'lowerbound', fullname: 'Quadratus femoris'},
# {alpha: 0.7, muscleNum: 21, bound: 'lowerbound', fullname: 'Quadratus femoris'},
# {alpha: 0.8, muscleNum: 21, bound: 'lowerbound', fullname: 'Quadratus femoris'},
# {alpha: 0.9, muscleNum: 21, bound: 'lowerbound', fullname: 'Quadratus femoris'},
# {alpha: 0.5, muscleNum: 22, bound: 'lowerbound', fullname: 'Rectus femoris'},
# {alpha: 0.6, muscleNum: 22, bound: 'lowerbound', fullname: 'Rectus femoris'},
# {alpha: 0.7, muscleNum: 22, bound: 'lowerbound', fullname: 'Rectus femoris'},
# {alpha: 0.8, muscleNum: 22, bound: 'lowerbound', fullname: 'Rectus femoris'},
# {alpha: 0.9, muscleNum: 22, bound: 'lowerbound', fullname: 'Rectus femoris'},
# {alpha: 0.5, muscleNum: 23, bound: 'lowerbound', fullname: 'Sartorius'},
# {alpha: 0.6, muscleNum: 23, bound: 'lowerbound', fullname: 'Sartorius'},
# {alpha: 0.7, muscleNum: 23, bound: 'lowerbound', fullname: 'Sartorius'},
# {alpha: 0.8, muscleNum: 23, bound: 'lowerbound', fullname: 'Sartorius'},
# {alpha: 0.9, muscleNum: 23, bound: 'lowerbound', fullname: 'Sartorius'},
# {alpha: 0.5, muscleNum: 24, bound: 'lowerbound', fullname: 'Semimembranossus'},
# {alpha: 0.6, muscleNum: 24, bound: 'lowerbound', fullname: 'Semimembranossus'},
# {alpha: 0.7, muscleNum: 24, bound: 'lowerbound', fullname: 'Semimembranossus'},
# {alpha: 0.8, muscleNum: 24, bound: 'lowerbound', fullname: 'Semimembranossus'},
# {alpha: 0.9, muscleNum: 24, bound: 'lowerbound', fullname: 'Semimembranossus'},
# {alpha: 0.5, muscleNum: 25, bound: 'lowerbound', fullname: 'Soleus'},
# {alpha: 0.6, muscleNum: 25, bound: 'lowerbound', fullname: 'Soleus'},
# {alpha: 0.7, muscleNum: 25, bound: 'lowerbound', fullname: 'Soleus'},
# {alpha: 0.8, muscleNum: 25, bound: 'lowerbound', fullname: 'Soleus'},
# {alpha: 0.9, muscleNum: 25, bound: 'lowerbound', fullname: 'Soleus'},
# {alpha: 0.5, muscleNum: 26, bound: 'lowerbound', fullname: 'Semitendinosus'},
# {alpha: 0.6, muscleNum: 26, bound: 'lowerbound', fullname: 'Semitendinosus'},
# {alpha: 0.7, muscleNum: 26, bound: 'lowerbound', fullname: 'Semitendinosus'},
# {alpha: 0.8, muscleNum: 26, bound: 'lowerbound', fullname: 'Semitendinosus'},
# {alpha: 0.9, muscleNum: 26, bound: 'lowerbound', fullname: 'Semitendinosus'},
# {alpha: 0.5, muscleNum: 27, bound: 'lowerbound', fullname: 'Tibialis anterior'},
# {alpha: 0.6, muscleNum: 27, bound: 'lowerbound', fullname: 'Tibialis anterior'},
# {alpha: 0.7, muscleNum: 27, bound: 'lowerbound', fullname: 'Tibialis anterior'},
# {alpha: 0.8, muscleNum: 27, bound: 'lowerbound', fullname: 'Tibialis anterior'},
# {alpha: 0.9, muscleNum: 27, bound: 'lowerbound', fullname: 'Tibialis anterior'},
# {alpha: 0.5, muscleNum: 28, bound: 'lowerbound', fullname: 'Tibialis posterior'},
# {alpha: 0.6, muscleNum: 28, bound: 'lowerbound', fullname: 'Tibialis posterior'},
# {alpha: 0.7, muscleNum: 28, bound: 'lowerbound', fullname: 'Tibialis posterior'},
# {alpha: 0.8, muscleNum: 28, bound: 'lowerbound', fullname: 'Tibialis posterior'},
# {alpha: 0.9, muscleNum: 28, bound: 'lowerbound', fullname: 'Tibialis posterior'},
# {alpha: 0.5, muscleNum: 29, bound: 'lowerbound', fullname: 'Vastus intermedius'},
# {alpha: 0.6, muscleNum: 29, bound: 'lowerbound', fullname: 'Vastus intermedius'},
# {alpha: 0.7, muscleNum: 29, bound: 'lowerbound', fullname: 'Vastus intermedius'},
# {alpha: 0.8, muscleNum: 29, bound: 'lowerbound', fullname: 'Vastus intermedius'},
# {alpha: 0.9, muscleNum: 29, bound: 'lowerbound', fullname: 'Vastus intermedius'},
# {alpha: 0.5, muscleNum: 30, bound: 'lowerbound', fullname: 'Vastus lateralis'},
# {alpha: 0.6, muscleNum: 30, bound: 'lowerbound', fullname: 'Vastus lateralis'},
# {alpha: 0.7, muscleNum: 30, bound: 'lowerbound', fullname: 'Vastus lateralis'},
# {alpha: 0.8, muscleNum: 30, bound: 'lowerbound', fullname: 'Vastus lateralis'},
# {alpha: 0.9, muscleNum: 30, bound: 'lowerbound', fullname: 'Vastus lateralis'},
# {alpha: 0.5, muscleNum: 31, bound: 'lowerbound', fullname: 'Vastus medialis'},
# {alpha: 0.6, muscleNum: 31, bound: 'lowerbound', fullname: 'Vastus medialis'},
# {alpha: 0.7, muscleNum: 31, bound: 'lowerbound', fullname: 'Vastus medialis'},
# {alpha: 0.8, muscleNum: 31, bound: 'lowerbound', fullname: 'Vastus medialis'},
# {alpha: 0.9, muscleNum: 31, bound: 'lowerbound', fullname: 'Vastus medialis'},
# ]
